# %%
import collections
import math
import os
import random
import zipfile

import numpy as np
import urllib
import tensorflow as tf
from IPython.display import Image

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0


# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.


graph = tf.Graph()
with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in range(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

  #%%
try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 200
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")


Image(filename='./tsne.png', width=1000)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a
# Initialized
# Average loss at step  0 :  273.4088134765625
# Nearest to s: postcard, chavez, surmised, jeeps, wedgwood, lenses, dix, mcclure,
# Nearest to war: exposes, tucson, protagoras, escort, compare, elkhart, corner, lapse,
# Nearest to it: luxuriant, been, kinetoscope, follies, litter, protest, drenthe, tar,
# Nearest to four: cacti, mandolins, dana, guiana, ontological, limbo, drying, chechnya,
# Nearest to when: immorality, tiergarten, milgram, musicians, aspirant, chadian, misandry, outsold,
# Nearest to eight: daytona, shirts, risked, rebounding, tamazight, bodmin, lubbers, goodies,
# Nearest to into: eliminating, martius, reassured, shag, conjoined, staffs, inputs, bei,
# Nearest to six: questionable, cargo, sufficiently, mond, expanse, lob, millimeters, dos,
# Nearest to a: declaring, peleus, mercantilist, probe, cora, banknotes, transitive, hellman,
# Nearest to also: brooke, windward, snes, thirty, collaborative, hurrians, marlin, phobia,
# Nearest to states: kaunas, tropes, blitzkrieg, szl, obfuscation, bleeding, trolley, babylon,
# Nearest to this: reasoning, skilled, dan, tanzania, elementary, pdp, marchers, pathways,
# Nearest to would: intermarriages, defiant, arabs, responsibilities, turkeys, federer, twayne, saccharomyces,
# Nearest to their: dostoevsky, absentee, nik, astrometric, contae, sarcophagus, salaam, sunrise,
# Nearest to some: awaited, til, andorran, espouses, jerome, hostility, neue, repeated,
# Nearest to after: roo, salem, gte, segmentata, hinders, sweep, nose, somebody,
# Average loss at step  2000 :  113.65332283592224
# Average loss at step  4000 :  52.51122631168366
# Average loss at step  6000 :  33.025232204675675
# Average loss at step  8000 :  23.665445262432097
# Average loss at step  10000 :  18.00663058567047
# Nearest to s: and, the, deny, carbon, grand, sensitive, of, hiv,
# Nearest to war: compare, corner, courts, android, nine, currently, rage, english,
# Nearest to it: protest, completeness, been, gonzales, they, and, reginae, tar,
# Nearest to four: reginae, zero, nine, asterism, two, seven, six, UNK,
# Nearest to when: immorality, is, musicians, briefly, for, pairs, economy, block,
# Nearest to eight: zero, pottery, nine, agave, victoriae, cl, gland, phi,
# Nearest to into: amo, phi, reproduction, university, two, reginae, exist, to,
# Nearest to six: zero, mond, questionable, nine, victoriae, phi, basins, gland,
# Nearest to a: the, and, UNK, one, victoriae, var, austin, psi,
# Nearest to also: brooke, told, saints, hooker, collaborative, and, americium, abdullah,
# Nearest to states: babylon, sri, nihon, opposition, sunlight, bleeding, vs, let,
# Nearest to this: reasoning, the, dan, elementary, feed, skilled, phi, basins,
# Nearest to would: arabs, afer, morocco, exacerbated, federer, organized, legacy, camus,
# Nearest to their: pottery, his, absentee, sarcophagus, alcohols, the, dostoevsky, montana,
# Nearest to some: the, expelled, constitutional, here, composer, repeated, basins, fay,
# Nearest to after: sweep, salem, cl, nose, scenic, ambients, of, regularly,
# Average loss at step  12000 :  14.021617832660676
# Average loss at step  14000 :  11.751568315267562
# Average loss at step  16000 :  9.915914891123771
# Average loss at step  18000 :  8.808520496964455
# Average loss at step  20000 :  7.936793586611747
# Nearest to s: and, the, zero, his, of, carbon, dasyprocta, reginae,
# Nearest to war: compare, tucson, corner, aquila, courts, athens, rage, android,
# Nearest to it: he, they, dasyprocta, agouti, protest, which, wilt, this,
# Nearest to four: seven, six, dasyprocta, two, zero, eight, nine, agouti,
# Nearest to when: is, for, immorality, was, dmt, musicians, shrimp, as,
# Nearest to eight: nine, zero, seven, six, five, two, agouti, three,
# Nearest to into: eliminating, in, and, reproduction, by, to, qaeda, absalom,
# Nearest to six: nine, eight, seven, zero, three, four, two, five,
# Nearest to a: the, dasyprocta, pottery, var, very, and, gollancz, zero,
# Nearest to also: which, brooke, crematoria, not, told, reverberation, hooker, saints,
# Nearest to states: sri, babylon, dasyprocta, nihon, bleeding, opposition, sunlight, elect,
# Nearest to this: the, reasoning, dan, agouti, it, phi, a, which,
# Nearest to would: may, arabs, ariane, exacerbated, truetype, afer, morocco, thirties,
# Nearest to their: his, the, its, dasyprocta, pottery, sarcophagus, agouti, absentee,
# Nearest to some: the, expelled, all, here, constitutional, clarendon, another, agouti,
# Nearest to after: sweep, of, metis, salem, in, nose, scenic, for,
# Average loss at step  22000 :  7.381451647877693
# Average loss at step  24000 :  6.9402392193079
# Average loss at step  26000 :  6.71462736749649
# Average loss at step  28000 :  6.178889717459679
# Average loss at step  30000 :  6.16214162760973
# Nearest to s: and, his, zero, the, of, dasyprocta, or, two,
# Nearest to war: compare, tucson, courts, trinomial, corner, android, aquila, protagoras,
# Nearest to it: he, this, they, she, which, there, dasyprocta, agouti,
# Nearest to four: eight, six, seven, three, five, nine, two, zero,
# Nearest to when: for, is, was, and, as, immorality, shrimp, dmt,
# Nearest to eight: nine, seven, six, five, four, zero, three, agouti,
# Nearest to into: in, eliminating, and, from, by, to, with, qaeda,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Nearest to a: the, dasyprocta, trinomial, very, victoriae, mishnayot, pottery, or,
# Nearest to also: which, often, not, brooke, hooker, crematoria, collaborative, reverberation,
# Nearest to states: babylon, sri, nihon, dasyprocta, bleeding, doctor, opposition, sunlight,
# Nearest to this: the, it, which, a, that, agouti, adhere, phi,
# Nearest to would: may, can, ariane, to, arabs, akh, but, exacerbated,
# Nearest to their: his, the, its, dasyprocta, sarcophagus, agouti, pottery, a,
# Nearest to some: the, all, many, expelled, this, another, here, annales,
# Nearest to after: from, in, sweep, metis, three, of, for, nose,
# Average loss at step  32000 :  5.879316282808781
# Average loss at step  34000 :  5.840517144083977
# Average loss at step  36000 :  5.686759585261345
# Average loss at step  38000 :  5.287257583618164
# Average loss at step  40000 :  5.505488059282303
# Nearest to s: and, his, zero, dasyprocta, gasolines, gimme, reginae, two,
# Nearest to war: compare, tucson, trinomial, courts, aquila, corner, android, protagoras,
# Nearest to it: he, she, this, which, they, there, not, agouti,
# Nearest to four: six, seven, three, eight, five, two, zero, one,
# Nearest to when: for, is, was, shrimp, seven, dmt, as, tiergarten,
# Nearest to eight: nine, seven, six, four, five, zero, three, dasyprocta,
# Nearest to into: from, eliminating, in, with, by, to, and, qaeda,
# Nearest to six: eight, four, seven, five, three, nine, zero, two,
# Nearest to a: the, gasolines, dasyprocta, trinomial, mishnayot, psi, this, var,
# Nearest to also: which, often, not, brooke, who, eruptions, it, reverberation,
# Nearest to states: babylon, sri, bleeding, nihon, dasyprocta, doctor, sunlight, opposition,
# Nearest to this: the, which, it, that, agouti, a, usually, adhere,
# Nearest to would: may, can, will, could, but, ariane, arabs, truetype,
# Nearest to their: his, its, the, dasyprocta, sds, sarcophagus, agouti, them,
# Nearest to some: many, the, all, expelled, annales, another, agouti, any,
# Nearest to after: from, six, during, sweep, at, seven, for, metis,
# Average loss at step  42000 :  5.322018997073173
# Average loss at step  44000 :  5.4210875730514525
# Average loss at step  46000 :  5.265255900859833
# Average loss at step  48000 :  5.005062358617782
# Average loss at step  50000 :  5.1552047085762025
# Nearest to s: his, and, thibetanus, zero, eight, of, godzilla, dasyprocta,
# Nearest to war: compare, tucson, trinomial, courts, rage, corner, humorist, android,
# Nearest to it: he, she, this, there, they, which, agouti, dasyprocta,
# Nearest to four: six, three, five, eight, seven, two, one, zero,
# Nearest to when: eight, for, seven, while, six, shrimp, is, dmt,
# Nearest to eight: six, seven, nine, four, five, three, zero, dasyprocta,
# Nearest to into: from, eliminating, with, by, through, in, havre, topical,
# Nearest to six: eight, four, three, seven, five, nine, two, zero,
# Nearest to a: the, gasolines, dasyprocta, mishnayot, thibetanus, trinomial, very, no,
# Nearest to also: which, often, not, thibetanus, eruptions, reverberation, it, now,
# Nearest to states: babylon, dasyprocta, nihon, bleeding, doctor, sunlight, sri, opposition,
# Nearest to this: which, it, the, agouti, that, usually, phi, adhere,
# Nearest to would: may, can, will, could, to, truetype, arabs, must,
# Nearest to their: his, its, the, them, dasyprocta, agouti, sds, wiltshire,
# Nearest to some: many, all, the, these, this, expelled, annales, agouti,
# Nearest to after: from, during, at, three, seven, as, sweep, reginae,
# Average loss at step  52000 :  5.175846119642258
# Average loss at step  54000 :  5.1208358505964275
# Average loss at step  56000 :  5.0503698282241825
# Average loss at step  58000 :  5.100380894422531
# Average loss at step  60000 :  4.9465602213740345
# Nearest to s: his, thibetanus, zero, and, gimme, godzilla, gasolines, usaid,
# Nearest to war: compare, rage, tucson, trinomial, courts, android, corner, athens,
# Nearest to it: he, this, she, there, which, they, agouti, dasyprocta,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to when: while, for, was, although, milah, dmt, six, espouses,
# Nearest to eight: nine, six, seven, four, five, zero, three, dasyprocta,
# Nearest to into: from, eliminating, with, through, havre, in, by, microcebus,
# Nearest to six: eight, four, five, seven, three, nine, zero, two,
# Nearest to a: the, gasolines, dasyprocta, mishnayot, trinomial, thibetanus, ssbn, tamarin,
# Nearest to also: often, which, not, eruptions, microcebus, never, thibetanus, victoriae,
# Nearest to states: babylon, blitzkrieg, dasyprocta, doctor, hbox, sunlight, kingdom, nihon,
# Nearest to this: which, it, the, that, usually, agouti, ssbn, some,
# Nearest to would: may, can, will, could, must, to, might, cannot,
# Nearest to their: its, his, the, them, dasyprocta, agouti, sds, gasolines,
# Nearest to some: many, all, these, the, cebus, other, any, this,
# Nearest to after: during, from, at, before, of, in, leontopithecus, gestation,
# Average loss at step  62000 :  4.809377216219902
# Average loss at step  64000 :  4.803621381878853
# Average loss at step  66000 :  4.981625589728355
# Average loss at step  68000 :  4.902100046753883
# Average loss at step  70000 :  4.768363620758056
# Nearest to s: his, thibetanus, gimme, usaid, and, gasolines, zero, the,
# Nearest to war: compare, tucson, trinomial, android, rage, courts, ferries, elizabeth,
# Nearest to it: he, this, she, there, they, which, agouti, dasyprocta,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to when: while, although, was, if, milah, for, espouses, eight,
# Nearest to eight: nine, six, seven, four, five, zero, three, thaler,
# Nearest to into: from, through, eliminating, havre, in, topical, with, to,
# Nearest to six: eight, four, seven, five, three, nine, zero, two,
# Nearest to a: the, gasolines, upanija, dasyprocta, mishnayot, thibetanus, ssbn, microcebus,
# Nearest to also: often, which, not, eruptions, never, now, microcebus, who,
# Nearest to states: dasyprocta, kingdom, babylon, hbox, cebus, blitzkrieg, doctor, sunlight,
# Nearest to this: which, it, the, that, agouti, usually, ssbn, thaler,
# Nearest to would: can, may, will, could, must, might, cannot, to,
# Nearest to their: its, his, the, thaler, them, wiltshire, dasyprocta, sds,
# Nearest to some: many, all, these, the, thaler, other, several, any,
# Nearest to after: during, at, before, from, in, leontopithecus, four, gestation,
# Average loss at step  72000 :  4.797195925712585
# Average loss at step  74000 :  4.783253750115633
# Average loss at step  76000 :  4.883653328120708
# Average loss at step  78000 :  4.799839111924172
# Average loss at step  80000 :  4.822503243565559
# Nearest to s: thibetanus, gimme, his, zero, cegep, and, usaid, reginae,
# Nearest to war: escuela, compare, android, tucson, elizabeth, rage, courts, trinomial,
# Nearest to it: he, this, she, there, which, they, dasyprocta, agouti,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to when: while, was, if, although, espouses, eight, during, however,
# Nearest to eight: seven, six, nine, four, five, three, zero, dasyprocta,
# Nearest to into: from, through, eliminating, with, in, topical, to, havre,
# Nearest to six: four, seven, five, eight, three, nine, two, zero,
# Nearest to a: the, gasolines, upanija, another, thibetanus, mishnayot, any, stingray,
# Nearest to also: often, which, eruptions, sometimes, never, now, cegep, still,
# Nearest to states: kingdom, dasyprocta, hbox, babylon, doctor, blitzkrieg, cebus, cegep,
# Nearest to this: which, it, the, that, agouti, usually, some, ssbn,
# Nearest to would: may, can, will, could, must, might, cannot, to,
# Nearest to their: its, his, the, thaler, her, dasyprocta, wiltshire, them,
# Nearest to some: many, all, these, thaler, several, other, the, this,
# Nearest to after: during, before, at, from, in, when, leontopithecus, reginae,
# Average loss at step  82000 :  4.793029116630554
# Average loss at step  84000 :  4.782575287699699
# Average loss at step  86000 :  4.7890811500549315
# Average loss at step  88000 :  4.696290058374405
# Average loss at step  90000 :  4.774908676028252
# Nearest to s: his, thibetanus, usaid, and, godzilla, gimme, gasolines, cegep,
# Nearest to war: escuela, tucson, android, elizabeth, compare, rage, trinomial, courts,
# Nearest to it: he, she, this, there, they, which, agouti, dasyprocta,
# Nearest to four: five, seven, eight, six, three, two, nine, one,
# Nearest to when: while, if, although, before, six, for, espouses, after,
# Nearest to eight: seven, five, six, nine, four, three, zero, thaler,
# Nearest to into: from, through, eliminating, with, topical, between, havre, microcebus,
# Nearest to six: seven, eight, five, four, three, nine, two, zero,
# Nearest to a: gasolines, the, upanija, dasyprocta, thibetanus, mishnayot, any, tamarin,
# Nearest to also: often, which, now, sometimes, eruptions, never, not, cegep,
# Nearest to states: kingdom, dasyprocta, hbox, babylon, blitzkrieg, bend, doctor, cegep,
# Nearest to this: which, it, the, that, agouti, some, usually, repulse,
# Nearest to would: may, will, can, could, must, might, cannot, should,
# Nearest to their: its, his, the, thaler, her, them, dasyprocta, agouti,
# Nearest to some: many, all, these, several, thaler, other, the, any,
# Nearest to after: during, before, at, when, from, leontopithecus, reginae, carotenoids,
# Average loss at step  92000 :  4.701206462144851
# Average loss at step  94000 :  4.634988053798676
# Average loss at step  96000 :  4.735770040392875
# Average loss at step  98000 :  4.619159220039845
# Average loss at step  100000 :  4.675609134197235
# Nearest to s: his, godzilla, thibetanus, gasolines, gimme, the, reginae, cegep,
# Nearest to war: escuela, tucson, android, elizabeth, compare, rage, trinomial, primrose,
# Nearest to it: he, she, this, there, they, which, usually, dasyprocta,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to when: if, while, although, after, and, before, where, until,
# Nearest to eight: seven, nine, six, five, four, three, zero, dasyprocta,
# Nearest to into: from, through, eliminating, with, in, to, topical, metabolites,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to a: gasolines, the, upanija, another, dasyprocta, mishnayot, any, thibetanus,
# Nearest to also: often, which, now, sometimes, never, eruptions, still, cegep,
# Nearest to states: kingdom, hbox, doctor, blitzkrieg, dasyprocta, babylon, bend, organisers,
# Nearest to this: which, it, the, that, agouti, some, usually, selamat,
# Nearest to would: will, may, can, could, must, might, cannot, should,
# Nearest to their: its, his, the, her, thaler, them, our, agouti,
# Nearest to some: many, these, all, several, thaler, any, other, the,
# Nearest to after: during, before, when, at, from, in, reginae, gestation,
